# %%
import os
import librosa
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import cv2

from sklearn.decomposition import PCA
import seaborn as sns

import torch
from torch.utils.data import Dataset, DataLoader

import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
from tqdm import tqdm

# %%
def load_reference_file(reference_path):
    """Load the reference CSV file containing labels."""
    try:
        reference_df = pd.read_csv(reference_path, header=None)
        reference_df.columns = ['filename', 'label']
        reference_df['filename'] += '.wav'  # Ensure filenames match
        reference_df.set_index('filename', inplace=True)
        return reference_df
    except Exception as e:
        raise FileNotFoundError(f"Could not read reference CSV: {e}")

# %%
def extract_mfcc_features(file_path, fixed_length=130):
    """Extract MFCC features from an audio file."""
    try:
        y, sr = librosa.load(file_path, sr=None)
        mfcc = librosa.feature.mfcc(y=y, sr=sr)
        
        # Padding or truncating MFCCs to the fixed length
        if mfcc.shape[1] < fixed_length:
            padding = fixed_length - mfcc.shape[1]
            mfcc = np.pad(mfcc, ((0, 0), (0, padding)), mode='constant')
        else:
            mfcc = mfcc[:, :fixed_length]
        
        return mfcc.flatten()
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None

# %%
def read_audio_files(data_path, reference_df, fixed_length=130):
    """Process audio files to extract MFCCs and their corresponding labels."""
    mfccs = []
    labels = []
    
    # Get sorted list of files
    file_list = sorted(os.listdir(data_path))
    
    for file in file_list:
        if file.endswith('.wav'):
            file_path = os.path.join(data_path, file)
            print(f"Processing file: {file_path}")  # Debugging line
            
            mfcc = extract_mfcc_features(file_path, fixed_length)
            if mfcc is not None:
                mfccs.append(mfcc)
                
                # Fetch label from the reference file
                if file in reference_df.index:
                    label = reference_df.loc[file, 'label']
                    labels.append(label)
                else:
                    print(f"Label for {file} not found in reference.csv. Skipping.")
    
    return np.array(mfccs), np.array(labels)

# %%
def process_dataset(base_path, folders, fixed_length=130):
    """Process multiple folders to extract MFCCs and labels."""
    all_mfccs = []
    all_labels = []
    
    for folder in folders:
        data_path = os.path.join(base_path, folder)
        reference_path = os.path.join(data_path, 'REFERENCE.csv')
        
        reference_df = load_reference_file(reference_path)
        folder_mfccs, folder_labels = read_audio_files(data_path, reference_df, fixed_length)
        
        all_mfccs.extend(folder_mfccs)
        all_labels.extend(folder_labels)
    
    return np.array(all_mfccs), np.array(all_labels)

# %%
base_path = './data/training_2016'

# %%
folders = ['training-a', 'training-b', 'training-c', 'training-d', 'training-e', 'training-f']

# %%
# Process the dataset and combine features and labels
all_mfccs, all_labels = process_dataset(base_path, folders);
# Out:
# Processing file: ./data/training_2016/training-a/a0001.wav
# Processing file: ./data/training_2016/training-a/a0002.wav
# Processing file: ./data/training_2016/training-a/a0003.wav
# Processing file: ./data/training_2016/training-a/a0004.wav
# Processing file: ./data/training_2016/training-a/a0005.wav
# Processing file: ./data/training_2016/training-a/a0006.wav
# Processing file: ./data/training_2016/training-a/a0007.wav
# Processing file: ./data/training_2016/training-a/a0008.wav
# Processing file: ./data/training_2016/training-a/a0009.wav
# Processing file: ./data/training_2016/training-a/a0010.wav
# Processing file: ./data/training_2016/training-a/a0011.wav
# Processing file: ./data/training_2016/training-a/a0012.wav
# Processing file: ./data/training_2016/training-a/a0013.wav
# Processing file: ./data/training_2016/training-a/a0014.wav
# Processing file: ./data/training_2016/training-a/a0015.wav
# Processing file: ./data/training_2016/training-a/a0016.wav
# Processing file: ./data/training_2016/training-a/a0017.wav
# Processing file: ./data/training_2016/training-a/a0018.wav
# Processing file: ./data/training_2016/training-a/a0019.wav
# Processing file: ./data/training_2016/training-a/a0020.wav
# Processing file: ./data/training_2016/training-a/a0021.wav
# Processing file: ./data/training_2016/training-a/a0022.wav
# Processing file: ./data/training_2016/training-a/a0023.wav
# Processing file: ./data/training_2016/training-a/a0024.wav
# Processing file: ./data/training_2016/training-a/a0025.wav
# Processing file: ./data/training_2016/training-a/a0026.wav
# Processing file: ./data/training_2016/training-a/a0027.wav
# Processing file: ./data/training_2016/training-a/a0028.wav
# Processing file: ./data/training_2016/training-a/a0029.wav
# Processing file: ./data/training_2016/training-a/a0030.wav
# Processing file: ./data/training_2016/training-a/a0031.wav
# Processing file: ./data/training_2016/training-a/a0032.wav
# Processing file: ./data/training_2016/training-a/a0033.wav
# Processing file: ./data/training_2016/training-a/a0034.wav
# Processing file: ./data/training_2016/training-a/a0035.wav
# Processing file: ./data/training_2016/training-a/a0036.wav
# Processing file: ./data/training_2016/training-a/a0037.wav
# Processing file: ./data/training_2016/training-a/a0038.wav
# Processing file: ./data/training_2016/training-a/a0039.wav
# Processing file: ./data/training_2016/training-a/a0040.wav
# Processing file: ./data/training_2016/training-a/a0041.wav
# Processing file: ./data/training_2016/training-a/a0042.wav
# Processing file: ./data/training_2016/training-a/a0043.wav
# Processing file: ./data/training_2016/training-a/a0044.wav
# Processing file: ./data/training_2016/training-a/a0045.wav
# Processing file: ./data/training_2016/training-a/a0046.wav
# Processing file: ./data/training_2016/training-a/a0047.wav
# Processing file: ./data/training_2016/training-a/a0048.wav
# Processing file: ./data/training_2016/training-a/a0049.wav
# Processing file: ./data/training_2016/training-a/a0050.wav
# Processing file: ./data/training_2016/training-a/a0051.wav
# Processing file: ./data/training_2016/training-a/a0052.wav
# Processing file: ./data/training_2016/training-a/a0053.wav
# Processing file: ./data/training_2016/training-a/a0054.wav
# Processing file: ./data/training_2016/training-a/a0055.wav
# Processing file: ./data/training_2016/training-a/a0056.wav
# Processing file: ./data/training_2016/training-a/a0057.wav
# Processing file: ./data/training_2016/training-a/a0058.wav
# Processing file: ./data/training_2016/training-a/a0059.wav
# Processing file: ./data/training_2016/training-a/a0060.wav
# Processing file: ./data/training_2016/training-a/a0061.wav
# Processing file: ./data/training_2016/training-a/a0062.wav
# Processing file: ./data/training_2016/training-a/a0063.wav
# Processing file: ./data/training_2016/training-a/a0064.wav
# Processing file: ./data/training_2016/training-a/a0065.wav
# Processing file: ./data/training_2016/training-a/a0066.wav
# Processing file: ./data/training_2016/training-a/a0067.wav
# Processing file: ./data/training_2016/training-a/a0068.wav
# Processing file: ./data/training_2016/training-a/a0069.wav
# Processing file: ./data/training_2016/training-a/a0070.wav
# Processing file: ./data/training_2016/training-a/a0071.wav
# Processing file: ./data/training_2016/training-a/a0072.wav
# Processing file: ./data/training_2016/training-a/a0073.wav
# Processing file: ./data/training_2016/training-a/a0074.wav
# Processing file: ./data/training_2016/training-a/a0075.wav
# Processing file: ./data/training_2016/training-a/a0076.wav
# Processing file: ./data/training_2016/training-a/a0077.wav
# Processing file: ./data/training_2016/training-a/a0078.wav
# Processing file: ./data/training_2016/training-a/a0079.wav
# Processing file: ./data/training_2016/training-a/a0080.wav
# Processing file: ./data/training_2016/training-a/a0081.wav
# Processing file: ./data/training_2016/training-a/a0082.wav
# Processing file: ./data/training_2016/training-a/a0083.wav
# Processing file: ./data/training_2016/training-a/a0084.wav
# Processing file: ./data/training_2016/training-a/a0085.wav
# Processing file: ./data/training_2016/training-a/a0086.wav
# Processing file: ./data/training_2016/training-a/a0087.wav
# Processing file: ./data/training_2016/training-a/a0088.wav
# Processing file: ./data/training_2016/training-a/a0089.wav
# Processing file: ./data/training_2016/training-a/a0090.wav
# Processing file: ./data/training_2016/training-a/a0091.wav
# Processing file: ./data/training_2016/training-a/a0092.wav
# Processing file: ./data/training_2016/training-a/a0093.wav
# Processing file: ./data/training_2016/training-a/a0094.wav
# Processing file: ./data/training_2016/training-a/a0095.wav
# Processing file: ./data/training_2016/training-a/a0096.wav
# Processing file: ./data/training_2016/training-a/a0097.wav
# Processing file: ./data/training_2016/training-a/a0098.wav
# Processing file: ./data/training_2016/training-a/a0099.wav
# Processing file: ./data/training_2016/training-a/a0100.wav
# Processing file: ./data/training_2016/training-a/a0101.wav
# Processing file: ./data/training_2016/training-a/a0102.wav
# Processing file: ./data/training_2016/training-a/a0103.wav
# Processing file: ./data/training_2016/training-a/a0104.wav
# Processing file: ./data/training_2016/training-a/a0105.wav
# Processing file: ./data/training_2016/training-a/a0106.wav
# Processing file: ./data/training_2016/training-a/a0107.wav
# Processing file: ./data/training_2016/training-a/a0108.wav
# Processing file: ./data/training_2016/training-a/a0109.wav
# Processing file: ./data/training_2016/training-a/a0110.wav
# Processing file: ./data/training_2016/training-a/a0111.wav
# Processing file: ./data/training_2016/training-a/a0112.wav
# Processing file: ./data/training_2016/training-a/a0113.wav
# Processing file: ./data/training_2016/training-a/a0114.wav
# Processing file: ./data/training_2016/training-a/a0115.wav
# Processing file: ./data/training_2016/training-a/a0116.wav
# Processing file: ./data/training_2016/training-a/a0117.wav
# Processing file: ./data/training_2016/training-a/a0118.wav
# Processing file: ./data/training_2016/training-a/a0119.wav
# Processing file: ./data/training_2016/training-a/a0120.wav
# Processing file: ./data/training_2016/training-a/a0121.wav
# Processing file: ./data/training_2016/training-a/a0122.wav
# Processing file: ./data/training_2016/training-a/a0123.wav
# Processing file: ./data/training_2016/training-a/a0124.wav
# Processing file: ./data/training_2016/training-a/a0125.wav
# Processing file: ./data/training_2016/training-a/a0126.wav
# Processing file: ./data/training_2016/training-a/a0127.wav
# Processing file: ./data/training_2016/training-a/a0128.wav
# Processing file: ./data/training_2016/training-a/a0129.wav
# Processing file: ./data/training_2016/training-a/a0130.wav
# Processing file: ./data/training_2016/training-a/a0131.wav
# Processing file: ./data/training_2016/training-a/a0132.wav
# Processing file: ./data/training_2016/training-a/a0133.wav
# Processing file: ./data/training_2016/training-a/a0134.wav
# Processing file: ./data/training_2016/training-a/a0135.wav
# Processing file: ./data/training_2016/training-a/a0136.wav
# Processing file: ./data/training_2016/training-a/a0137.wav
# Processing file: ./data/training_2016/training-a/a0138.wav
# Processing file: ./data/training_2016/training-a/a0139.wav
# Processing file: ./data/training_2016/training-a/a0140.wav
# Processing file: ./data/training_2016/training-a/a0141.wav
# Processing file: ./data/training_2016/training-a/a0142.wav
# Processing file: ./data/training_2016/training-a/a0143.wav
# Processing file: ./data/training_2016/training-a/a0144.wav
# Processing file: ./data/training_2016/training-a/a0145.wav
# Processing file: ./data/training_2016/training-a/a0146.wav
# Processing file: ./data/training_2016/training-a/a0147.wav
# Processing file: ./data/training_2016/training-a/a0148.wav
# Processing file: ./data/training_2016/training-a/a0149.wav
# Processing file: ./data/training_2016/training-a/a0150.wav
# Processing file: ./data/training_2016/training-a/a0151.wav
# Processing file: ./data/training_2016/training-a/a0152.wav
# Processing file: ./data/training_2016/training-a/a0153.wav
# Processing file: ./data/training_2016/training-a/a0154.wav
# Processing file: ./data/training_2016/training-a/a0155.wav
# Processing file: ./data/training_2016/training-a/a0156.wav
# Processing file: ./data/training_2016/training-a/a0157.wav
# Processing file: ./data/training_2016/training-a/a0158.wav
# Processing file: ./data/training_2016/training-a/a0159.wav
# Processing file: ./data/training_2016/training-a/a0160.wav
# Processing file: ./data/training_2016/training-a/a0161.wav
# Processing file: ./data/training_2016/training-a/a0162.wav
# Processing file: ./data/training_2016/training-a/a0163.wav
# Processing file: ./data/training_2016/training-a/a0164.wav
# Processing file: ./data/training_2016/training-a/a0165.wav
# Processing file: ./data/training_2016/training-a/a0166.wav
# Processing file: ./data/training_2016/training-a/a0167.wav
# Processing file: ./data/training_2016/training-a/a0168.wav
# Processing file: ./data/training_2016/training-a/a0169.wav
# Processing file: ./data/training_2016/training-a/a0170.wav
# Processing file: ./data/training_2016/training-a/a0171.wav
# Processing file: ./data/training_2016/training-a/a0172.wav
# Processing file: ./data/training_2016/training-a/a0173.wav
# Processing file: ./data/training_2016/training-a/a0174.wav
# Processing file: ./data/training_2016/training-a/a0175.wav
# Processing file: ./data/training_2016/training-a/a0176.wav
# Processing file: ./data/training_2016/training-a/a0177.wav
# Processing file: ./data/training_2016/training-a/a0178.wav
# Processing file: ./data/training_2016/training-a/a0179.wav
# Processing file: ./data/training_2016/training-a/a0180.wav
# Processing file: ./data/training_2016/training-a/a0181.wav
# Processing file: ./data/training_2016/training-a/a0182.wav
# Processing file: ./data/training_2016/training-a/a0183.wav
# Processing file: ./data/training_2016/training-a/a0184.wav
# Processing file: ./data/training_2016/training-a/a0185.wav
# Processing file: ./data/training_2016/training-a/a0186.wav
# Processing file: ./data/training_2016/training-a/a0187.wav
# Processing file: ./data/training_2016/training-a/a0188.wav
# Processing file: ./data/training_2016/training-a/a0189.wav
# Processing file: ./data/training_2016/training-a/a0190.wav
# Processing file: ./data/training_2016/training-a/a0191.wav
# Processing file: ./data/training_2016/training-a/a0192.wav
# Processing file: ./data/training_2016/training-a/a0193.wav
# Processing file: ./data/training_2016/training-a/a0194.wav
# Processing file: ./data/training_2016/training-a/a0195.wav
# Processing file: ./data/training_2016/training-a/a0196.wav
# Processing file: ./data/training_2016/training-a/a0197.wav
# Processing file: ./data/training_2016/training-a/a0198.wav
# Processing file: ./data/training_2016/training-a/a0199.wav
# Processing file: ./data/training_2016/training-a/a0200.wav
# Processing file: ./data/training_2016/training-a/a0201.wav
# Processing file: ./data/training_2016/training-a/a0202.wav
# Processing file: ./data/training_2016/training-a/a0203.wav
# Processing file: ./data/training_2016/training-a/a0204.wav
# Processing file: ./data/training_2016/training-a/a0205.wav
# Processing file: ./data/training_2016/training-a/a0206.wav
# Processing file: ./data/training_2016/training-a/a0207.wav
# Processing file: ./data/training_2016/training-a/a0208.wav
# Processing file: ./data/training_2016/training-a/a0209.wav
# Processing file: ./data/training_2016/training-a/a0210.wav
# Processing file: ./data/training_2016/training-a/a0211.wav
# Processing file: ./data/training_2016/training-a/a0212.wav
# Processing file: ./data/training_2016/training-a/a0213.wav
# Processing file: ./data/training_2016/training-a/a0214.wav
# Processing file: ./data/training_2016/training-a/a0215.wav
# Processing file: ./data/training_2016/training-a/a0216.wav
# Processing file: ./data/training_2016/training-a/a0217.wav
# Processing file: ./data/training_2016/training-a/a0218.wav
# Processing file: ./data/training_2016/training-a/a0219.wav
# Processing file: ./data/training_2016/training-a/a0220.wav
# Processing file: ./data/training_2016/training-a/a0221.wav
# Processing file: ./data/training_2016/training-a/a0222.wav
# Processing file: ./data/training_2016/training-a/a0223.wav
# Processing file: ./data/training_2016/training-a/a0224.wav
# Processing file: ./data/training_2016/training-a/a0225.wav
# Processing file: ./data/training_2016/training-a/a0226.wav
# Processing file: ./data/training_2016/training-a/a0227.wav
# Processing file: ./data/training_2016/training-a/a0228.wav
# Processing file: ./data/training_2016/training-a/a0229.wav
# Processing file: ./data/training_2016/training-a/a0230.wav
# Processing file: ./data/training_2016/training-a/a0231.wav
# Processing file: ./data/training_2016/training-a/a0232.wav
# Processing file: ./data/training_2016/training-a/a0233.wav
# Processing file: ./data/training_2016/training-a/a0234.wav
# Processing file: ./data/training_2016/training-a/a0235.wav
# Processing file: ./data/training_2016/training-a/a0236.wav
# Processing file: ./data/training_2016/training-a/a0237.wav
# Processing file: ./data/training_2016/training-a/a0238.wav
# Processing file: ./data/training_2016/training-a/a0239.wav
# Processing file: ./data/training_2016/training-a/a0240.wav
# Processing file: ./data/training_2016/training-a/a0241.wav
# Processing file: ./data/training_2016/training-a/a0242.wav
# Processing file: ./data/training_2016/training-a/a0243.wav
# Processing file: ./data/training_2016/training-a/a0244.wav
# Processing file: ./data/training_2016/training-a/a0245.wav
# Processing file: ./data/training_2016/training-a/a0246.wav
# Processing file: ./data/training_2016/training-a/a0247.wav
# Processing file: ./data/training_2016/training-a/a0248.wav
# Processing file: ./data/training_2016/training-a/a0249.wav
# Processing file: ./data/training_2016/training-a/a0250.wav
# Processing file: ./data/training_2016/training-a/a0251.wav
# Processing file: ./data/training_2016/training-a/a0252.wav
# Processing file: ./data/training_2016/training-a/a0253.wav
# Processing file: ./data/training_2016/training-a/a0254.wav
# Processing file: ./data/training_2016/training-a/a0255.wav
# Processing file: ./data/training_2016/training-a/a0256.wav
# Processing file: ./data/training_2016/training-a/a0257.wav
# Processing file: ./data/training_2016/training-a/a0258.wav
# Processing file: ./data/training_2016/training-a/a0259.wav
# Processing file: ./data/training_2016/training-a/a0260.wav
# Processing file: ./data/training_2016/training-a/a0261.wav
# Processing file: ./data/training_2016/training-a/a0262.wav
# Processing file: ./data/training_2016/training-a/a0263.wav
# Processing file: ./data/training_2016/training-a/a0264.wav
# Processing file: ./data/training_2016/training-a/a0265.wav
# Processing file: ./data/training_2016/training-a/a0266.wav
# Processing file: ./data/training_2016/training-a/a0267.wav
# Processing file: ./data/training_2016/training-a/a0268.wav
# Processing file: ./data/training_2016/training-a/a0269.wav
# Processing file: ./data/training_2016/training-a/a0270.wav
# Processing file: ./data/training_2016/training-a/a0271.wav
# Processing file: ./data/training_2016/training-a/a0272.wav
# Processing file: ./data/training_2016/training-a/a0273.wav
# Processing file: ./data/training_2016/training-a/a0274.wav
# Processing file: ./data/training_2016/training-a/a0275.wav
# Processing file: ./data/training_2016/training-a/a0276.wav
# Processing file: ./data/training_2016/training-a/a0277.wav
# Processing file: ./data/training_2016/training-a/a0278.wav
# Processing file: ./data/training_2016/training-a/a0279.wav
# Processing file: ./data/training_2016/training-a/a0280.wav
# Processing file: ./data/training_2016/training-a/a0281.wav
# Processing file: ./data/training_2016/training-a/a0282.wav
# Processing file: ./data/training_2016/training-a/a0283.wav
# Processing file: ./data/training_2016/training-a/a0284.wav
# Processing file: ./data/training_2016/training-a/a0285.wav
# Processing file: ./data/training_2016/training-a/a0286.wav
# Processing file: ./data/training_2016/training-a/a0287.wav
# Processing file: ./data/training_2016/training-a/a0288.wav
# Processing file: ./data/training_2016/training-a/a0289.wav
# Processing file: ./data/training_2016/training-a/a0290.wav
# Processing file: ./data/training_2016/training-a/a0291.wav
# Processing file: ./data/training_2016/training-a/a0292.wav
# Processing file: ./data/training_2016/training-a/a0293.wav
# Processing file: ./data/training_2016/training-a/a0294.wav
# Processing file: ./data/training_2016/training-a/a0295.wav
# Processing file: ./data/training_2016/training-a/a0296.wav
# Processing file: ./data/training_2016/training-a/a0297.wav
# Processing file: ./data/training_2016/training-a/a0298.wav
# Processing file: ./data/training_2016/training-a/a0299.wav
# Processing file: ./data/training_2016/training-a/a0300.wav
# Processing file: ./data/training_2016/training-a/a0301.wav
# Processing file: ./data/training_2016/training-a/a0302.wav
# Processing file: ./data/training_2016/training-a/a0303.wav
# Processing file: ./data/training_2016/training-a/a0304.wav
# Processing file: ./data/training_2016/training-a/a0305.wav
# Processing file: ./data/training_2016/training-a/a0306.wav
# Processing file: ./data/training_2016/training-a/a0307.wav
# Processing file: ./data/training_2016/training-a/a0308.wav
# Processing file: ./data/training_2016/training-a/a0309.wav
# Processing file: ./data/training_2016/training-a/a0310.wav
# Processing file: ./data/training_2016/training-a/a0311.wav
# Processing file: ./data/training_2016/training-a/a0312.wav
# Processing file: ./data/training_2016/training-a/a0313.wav
# Processing file: ./data/training_2016/training-a/a0314.wav
# Processing file: ./data/training_2016/training-a/a0315.wav
# Processing file: ./data/training_2016/training-a/a0316.wav
# Processing file: ./data/training_2016/training-a/a0317.wav
# Processing file: ./data/training_2016/training-a/a0318.wav
# Processing file: ./data/training_2016/training-a/a0319.wav
# Processing file: ./data/training_2016/training-a/a0320.wav
# Processing file: ./data/training_2016/training-a/a0321.wav
# Processing file: ./data/training_2016/training-a/a0322.wav
# Processing file: ./data/training_2016/training-a/a0323.wav
# Processing file: ./data/training_2016/training-a/a0324.wav
# Processing file: ./data/training_2016/training-a/a0325.wav
# Processing file: ./data/training_2016/training-a/a0326.wav
# Processing file: ./data/training_2016/training-a/a0327.wav
# Processing file: ./data/training_2016/training-a/a0328.wav
# Processing file: ./data/training_2016/training-a/a0329.wav
# Processing file: ./data/training_2016/training-a/a0330.wav
# Processing file: ./data/training_2016/training-a/a0331.wav
# Processing file: ./data/training_2016/training-a/a0332.wav
# Processing file: ./data/training_2016/training-a/a0333.wav
# Processing file: ./data/training_2016/training-a/a0334.wav
# Processing file: ./data/training_2016/training-a/a0335.wav
# Processing file: ./data/training_2016/training-a/a0336.wav
# Processing file: ./data/training_2016/training-a/a0337.wav
# Processing file: ./data/training_2016/training-a/a0338.wav
# Processing file: ./data/training_2016/training-a/a0339.wav
# Processing file: ./data/training_2016/training-a/a0340.wav
# Processing file: ./data/training_2016/training-a/a0341.wav
# Processing file: ./data/training_2016/training-a/a0342.wav
# Processing file: ./data/training_2016/training-a/a0343.wav
# Processing file: ./data/training_2016/training-a/a0344.wav
# Processing file: ./data/training_2016/training-a/a0345.wav
# Processing file: ./data/training_2016/training-a/a0346.wav
# Processing file: ./data/training_2016/training-a/a0347.wav
# Processing file: ./data/training_2016/training-a/a0348.wav
# Processing file: ./data/training_2016/training-a/a0349.wav
# Processing file: ./data/training_2016/training-a/a0350.wav
# Processing file: ./data/training_2016/training-a/a0351.wav
# Processing file: ./data/training_2016/training-a/a0352.wav
# Processing file: ./data/training_2016/training-a/a0353.wav
# Processing file: ./data/training_2016/training-a/a0354.wav
# Processing file: ./data/training_2016/training-a/a0355.wav
# Processing file: ./data/training_2016/training-a/a0356.wav
# Processing file: ./data/training_2016/training-a/a0357.wav
# Processing file: ./data/training_2016/training-a/a0358.wav
# Processing file: ./data/training_2016/training-a/a0359.wav
# Processing file: ./data/training_2016/training-a/a0360.wav
# Processing file: ./data/training_2016/training-a/a0361.wav
# Processing file: ./data/training_2016/training-a/a0362.wav
# Processing file: ./data/training_2016/training-a/a0363.wav
# Processing file: ./data/training_2016/training-a/a0364.wav
# Processing file: ./data/training_2016/training-a/a0365.wav
# Processing file: ./data/training_2016/training-a/a0366.wav
# Processing file: ./data/training_2016/training-a/a0367.wav
# Processing file: ./data/training_2016/training-a/a0368.wav
# Processing file: ./data/training_2016/training-a/a0369.wav
# Processing file: ./data/training_2016/training-a/a0370.wav
# Processing file: ./data/training_2016/training-a/a0371.wav
# Processing file: ./data/training_2016/training-a/a0372.wav
# Processing file: ./data/training_2016/training-a/a0373.wav
# Processing file: ./data/training_2016/training-a/a0374.wav
# Processing file: ./data/training_2016/training-a/a0375.wav
# Processing file: ./data/training_2016/training-a/a0376.wav
# Processing file: ./data/training_2016/training-a/a0377.wav
# Processing file: ./data/training_2016/training-a/a0378.wav
# Processing file: ./data/training_2016/training-a/a0379.wav
# Processing file: ./data/training_2016/training-a/a0380.wav
# Processing file: ./data/training_2016/training-a/a0381.wav
# Processing file: ./data/training_2016/training-a/a0382.wav
# Processing file: ./data/training_2016/training-a/a0383.wav
# Processing file: ./data/training_2016/training-a/a0384.wav
# Processing file: ./data/training_2016/training-a/a0385.wav
# Processing file: ./data/training_2016/training-a/a0386.wav
# Processing file: ./data/training_2016/training-a/a0387.wav
# Processing file: ./data/training_2016/training-a/a0388.wav
# Processing file: ./data/training_2016/training-a/a0389.wav
# Processing file: ./data/training_2016/training-a/a0390.wav
# Processing file: ./data/training_2016/training-a/a0391.wav
# Processing file: ./data/training_2016/training-a/a0392.wav
# Processing file: ./data/training_2016/training-a/a0393.wav
# Processing file: ./data/training_2016/training-a/a0394.wav
# Processing file: ./data/training_2016/training-a/a0395.wav
# Processing file: ./data/training_2016/training-a/a0396.wav
# Processing file: ./data/training_2016/training-a/a0397.wav
# Processing file: ./data/training_2016/training-a/a0398.wav
# Processing file: ./data/training_2016/training-a/a0399.wav
# Processing file: ./data/training_2016/training-a/a0400.wav
# Processing file: ./data/training_2016/training-a/a0401.wav
# Processing file: ./data/training_2016/training-a/a0402.wav
# Processing file: ./data/training_2016/training-a/a0403.wav
# Processing file: ./data/training_2016/training-a/a0404.wav
# Processing file: ./data/training_2016/training-a/a0405.wav
# Processing file: ./data/training_2016/training-a/a0406.wav
# Processing file: ./data/training_2016/training-a/a0407.wav
# Processing file: ./data/training_2016/training-a/a0408.wav
# Processing file: ./data/training_2016/training-a/a0409.wav
# Processing file: ./data/training_2016/training-b/b0001.wav
# Processing file: ./data/training_2016/training-b/b0002.wav
# Processing file: ./data/training_2016/training-b/b0003.wav
# Processing file: ./data/training_2016/training-b/b0004.wav
# Processing file: ./data/training_2016/training-b/b0005.wav
# Processing file: ./data/training_2016/training-b/b0006.wav
# Processing file: ./data/training_2016/training-b/b0007.wav
# Processing file: ./data/training_2016/training-b/b0008.wav
# Processing file: ./data/training_2016/training-b/b0009.wav
# Processing file: ./data/training_2016/training-b/b0010.wav
# Processing file: ./data/training_2016/training-b/b0011.wav
# Processing file: ./data/training_2016/training-b/b0012.wav
# Processing file: ./data/training_2016/training-b/b0013.wav
# Processing file: ./data/training_2016/training-b/b0014.wav
# Processing file: ./data/training_2016/training-b/b0015.wav
# Processing file: ./data/training_2016/training-b/b0016.wav
# Processing file: ./data/training_2016/training-b/b0017.wav
# Processing file: ./data/training_2016/training-b/b0018.wav
# Processing file: ./data/training_2016/training-b/b0019.wav
# Processing file: ./data/training_2016/training-b/b0020.wav
# Processing file: ./data/training_2016/training-b/b0021.wav
# Processing file: ./data/training_2016/training-b/b0022.wav
# Processing file: ./data/training_2016/training-b/b0023.wav
# Processing file: ./data/training_2016/training-b/b0024.wav
# Processing file: ./data/training_2016/training-b/b0025.wav
# Processing file: ./data/training_2016/training-b/b0026.wav
# Processing file: ./data/training_2016/training-b/b0027.wav
# Processing file: ./data/training_2016/training-b/b0028.wav
# Processing file: ./data/training_2016/training-b/b0029.wav
# Processing file: ./data/training_2016/training-b/b0030.wav
# Processing file: ./data/training_2016/training-b/b0031.wav
# Processing file: ./data/training_2016/training-b/b0032.wav
# Processing file: ./data/training_2016/training-b/b0033.wav
# Processing file: ./data/training_2016/training-b/b0034.wav
# Processing file: ./data/training_2016/training-b/b0035.wav
# Processing file: ./data/training_2016/training-b/b0036.wav
# Processing file: ./data/training_2016/training-b/b0037.wav
# Processing file: ./data/training_2016/training-b/b0038.wav
# Processing file: ./data/training_2016/training-b/b0039.wav
# Processing file: ./data/training_2016/training-b/b0040.wav
# Processing file: ./data/training_2016/training-b/b0041.wav
# Processing file: ./data/training_2016/training-b/b0042.wav
# Processing file: ./data/training_2016/training-b/b0043.wav
# Processing file: ./data/training_2016/training-b/b0044.wav
# Processing file: ./data/training_2016/training-b/b0045.wav
# Processing file: ./data/training_2016/training-b/b0046.wav
# Processing file: ./data/training_2016/training-b/b0047.wav
# Processing file: ./data/training_2016/training-b/b0048.wav
# Processing file: ./data/training_2016/training-b/b0049.wav
# Processing file: ./data/training_2016/training-b/b0050.wav
# Processing file: ./data/training_2016/training-b/b0051.wav
# Processing file: ./data/training_2016/training-b/b0052.wav
# Processing file: ./data/training_2016/training-b/b0053.wav
# Processing file: ./data/training_2016/training-b/b0054.wav
# Processing file: ./data/training_2016/training-b/b0055.wav
# Processing file: ./data/training_2016/training-b/b0056.wav
# Processing file: ./data/training_2016/training-b/b0057.wav
# Processing file: ./data/training_2016/training-b/b0058.wav
# Processing file: ./data/training_2016/training-b/b0059.wav
# Processing file: ./data/training_2016/training-b/b0060.wav
# Processing file: ./data/training_2016/training-b/b0061.wav
# Processing file: ./data/training_2016/training-b/b0062.wav
# Processing file: ./data/training_2016/training-b/b0063.wav
# Processing file: ./data/training_2016/training-b/b0064.wav
# Processing file: ./data/training_2016/training-b/b0065.wav
# Processing file: ./data/training_2016/training-b/b0066.wav
# Processing file: ./data/training_2016/training-b/b0067.wav
# Processing file: ./data/training_2016/training-b/b0068.wav
# Processing file: ./data/training_2016/training-b/b0069.wav
# Processing file: ./data/training_2016/training-b/b0070.wav
# Processing file: ./data/training_2016/training-b/b0071.wav
# Processing file: ./data/training_2016/training-b/b0072.wav
# Processing file: ./data/training_2016/training-b/b0073.wav
# Processing file: ./data/training_2016/training-b/b0074.wav
# Processing file: ./data/training_2016/training-b/b0075.wav
# Processing file: ./data/training_2016/training-b/b0076.wav
# Processing file: ./data/training_2016/training-b/b0077.wav
# Processing file: ./data/training_2016/training-b/b0078.wav
# Processing file: ./data/training_2016/training-b/b0079.wav
# Processing file: ./data/training_2016/training-b/b0080.wav
# Processing file: ./data/training_2016/training-b/b0081.wav
# Processing file: ./data/training_2016/training-b/b0082.wav
# Processing file: ./data/training_2016/training-b/b0083.wav
# Processing file: ./data/training_2016/training-b/b0084.wav
# Processing file: ./data/training_2016/training-b/b0085.wav
# Processing file: ./data/training_2016/training-b/b0086.wav
# Processing file: ./data/training_2016/training-b/b0087.wav
# Processing file: ./data/training_2016/training-b/b0088.wav
# Processing file: ./data/training_2016/training-b/b0089.wav
# Processing file: ./data/training_2016/training-b/b0090.wav
# Processing file: ./data/training_2016/training-b/b0091.wav
# Processing file: ./data/training_2016/training-b/b0092.wav
# Processing file: ./data/training_2016/training-b/b0093.wav
# Processing file: ./data/training_2016/training-b/b0094.wav
# Processing file: ./data/training_2016/training-b/b0095.wav
# Processing file: ./data/training_2016/training-b/b0096.wav
# Processing file: ./data/training_2016/training-b/b0097.wav
# Processing file: ./data/training_2016/training-b/b0098.wav
# Processing file: ./data/training_2016/training-b/b0099.wav
# Processing file: ./data/training_2016/training-b/b0100.wav
# Processing file: ./data/training_2016/training-b/b0101.wav
# Processing file: ./data/training_2016/training-b/b0102.wav
# Processing file: ./data/training_2016/training-b/b0103.wav
# Processing file: ./data/training_2016/training-b/b0104.wav
# Processing file: ./data/training_2016/training-b/b0105.wav
# Processing file: ./data/training_2016/training-b/b0106.wav
# Processing file: ./data/training_2016/training-b/b0107.wav
# Processing file: ./data/training_2016/training-b/b0108.wav
# Processing file: ./data/training_2016/training-b/b0109.wav
# Processing file: ./data/training_2016/training-b/b0110.wav
# Processing file: ./data/training_2016/training-b/b0111.wav
# Processing file: ./data/training_2016/training-b/b0112.wav
# Processing file: ./data/training_2016/training-b/b0113.wav
# Processing file: ./data/training_2016/training-b/b0114.wav
# Processing file: ./data/training_2016/training-b/b0115.wav
# Processing file: ./data/training_2016/training-b/b0116.wav
# Processing file: ./data/training_2016/training-b/b0117.wav
# Processing file: ./data/training_2016/training-b/b0118.wav
# Processing file: ./data/training_2016/training-b/b0119.wav
# Processing file: ./data/training_2016/training-b/b0120.wav
# Processing file: ./data/training_2016/training-b/b0121.wav
# Processing file: ./data/training_2016/training-b/b0122.wav
# Processing file: ./data/training_2016/training-b/b0123.wav
# Processing file: ./data/training_2016/training-b/b0124.wav
# Processing file: ./data/training_2016/training-b/b0125.wav
# Processing file: ./data/training_2016/training-b/b0126.wav
# Processing file: ./data/training_2016/training-b/b0127.wav
# Processing file: ./data/training_2016/training-b/b0128.wav
# Processing file: ./data/training_2016/training-b/b0129.wav
# Processing file: ./data/training_2016/training-b/b0130.wav
# Processing file: ./data/training_2016/training-b/b0131.wav
# Processing file: ./data/training_2016/training-b/b0132.wav
# Processing file: ./data/training_2016/training-b/b0133.wav
# Processing file: ./data/training_2016/training-b/b0134.wav
# Processing file: ./data/training_2016/training-b/b0135.wav
# Processing file: ./data/training_2016/training-b/b0136.wav
# Processing file: ./data/training_2016/training-b/b0137.wav
# Processing file: ./data/training_2016/training-b/b0138.wav
# Processing file: ./data/training_2016/training-b/b0139.wav
# Processing file: ./data/training_2016/training-b/b0140.wav
# Processing file: ./data/training_2016/training-b/b0141.wav
# Processing file: ./data/training_2016/training-b/b0142.wav
# Processing file: ./data/training_2016/training-b/b0143.wav
# Processing file: ./data/training_2016/training-b/b0144.wav
# Processing file: ./data/training_2016/training-b/b0145.wav
# Processing file: ./data/training_2016/training-b/b0146.wav
# Processing file: ./data/training_2016/training-b/b0147.wav
# Processing file: ./data/training_2016/training-b/b0148.wav
# Processing file: ./data/training_2016/training-b/b0149.wav
# Processing file: ./data/training_2016/training-b/b0150.wav
# Processing file: ./data/training_2016/training-b/b0151.wav
# Processing file: ./data/training_2016/training-b/b0152.wav
# Processing file: ./data/training_2016/training-b/b0153.wav
# Processing file: ./data/training_2016/training-b/b0154.wav
# Processing file: ./data/training_2016/training-b/b0155.wav
# Processing file: ./data/training_2016/training-b/b0156.wav
# Processing file: ./data/training_2016/training-b/b0157.wav
# Processing file: ./data/training_2016/training-b/b0158.wav
# Processing file: ./data/training_2016/training-b/b0159.wav
# Processing file: ./data/training_2016/training-b/b0160.wav
# Processing file: ./data/training_2016/training-b/b0161.wav
# Processing file: ./data/training_2016/training-b/b0162.wav
# Processing file: ./data/training_2016/training-b/b0163.wav
# Processing file: ./data/training_2016/training-b/b0164.wav
# Processing file: ./data/training_2016/training-b/b0165.wav
# Processing file: ./data/training_2016/training-b/b0166.wav
# Processing file: ./data/training_2016/training-b/b0167.wav
# Processing file: ./data/training_2016/training-b/b0168.wav
# Processing file: ./data/training_2016/training-b/b0169.wav
# Processing file: ./data/training_2016/training-b/b0170.wav
# Processing file: ./data/training_2016/training-b/b0171.wav
# Processing file: ./data/training_2016/training-b/b0172.wav
# Processing file: ./data/training_2016/training-b/b0173.wav
# Processing file: ./data/training_2016/training-b/b0174.wav
# Processing file: ./data/training_2016/training-b/b0175.wav
# Processing file: ./data/training_2016/training-b/b0176.wav
# Processing file: ./data/training_2016/training-b/b0177.wav
# Processing file: ./data/training_2016/training-b/b0178.wav
# Processing file: ./data/training_2016/training-b/b0179.wav
# Processing file: ./data/training_2016/training-b/b0180.wav
# Processing file: ./data/training_2016/training-b/b0181.wav
# Processing file: ./data/training_2016/training-b/b0182.wav
# Processing file: ./data/training_2016/training-b/b0183.wav
# Processing file: ./data/training_2016/training-b/b0184.wav
# Processing file: ./data/training_2016/training-b/b0185.wav
# Processing file: ./data/training_2016/training-b/b0186.wav
# Processing file: ./data/training_2016/training-b/b0187.wav
# Processing file: ./data/training_2016/training-b/b0188.wav
# Processing file: ./data/training_2016/training-b/b0189.wav
# Processing file: ./data/training_2016/training-b/b0190.wav
# Processing file: ./data/training_2016/training-b/b0191.wav
# Processing file: ./data/training_2016/training-b/b0192.wav
# Processing file: ./data/training_2016/training-b/b0193.wav
# Processing file: ./data/training_2016/training-b/b0194.wav
# Processing file: ./data/training_2016/training-b/b0195.wav
# Processing file: ./data/training_2016/training-b/b0196.wav
# Processing file: ./data/training_2016/training-b/b0197.wav
# Processing file: ./data/training_2016/training-b/b0198.wav
# Processing file: ./data/training_2016/training-b/b0199.wav
# Processing file: ./data/training_2016/training-b/b0200.wav
# Processing file: ./data/training_2016/training-b/b0201.wav
# Processing file: ./data/training_2016/training-b/b0202.wav
# Processing file: ./data/training_2016/training-b/b0203.wav
# Processing file: ./data/training_2016/training-b/b0204.wav
# Processing file: ./data/training_2016/training-b/b0205.wav
# Processing file: ./data/training_2016/training-b/b0206.wav
# Processing file: ./data/training_2016/training-b/b0207.wav
# Processing file: ./data/training_2016/training-b/b0208.wav
# Processing file: ./data/training_2016/training-b/b0209.wav
# Processing file: ./data/training_2016/training-b/b0210.wav
# Processing file: ./data/training_2016/training-b/b0211.wav
# Processing file: ./data/training_2016/training-b/b0212.wav
# Processing file: ./data/training_2016/training-b/b0213.wav
# Processing file: ./data/training_2016/training-b/b0214.wav
# Processing file: ./data/training_2016/training-b/b0215.wav
# Processing file: ./data/training_2016/training-b/b0216.wav
# Processing file: ./data/training_2016/training-b/b0217.wav
# Processing file: ./data/training_2016/training-b/b0218.wav
# Processing file: ./data/training_2016/training-b/b0219.wav
# Processing file: ./data/training_2016/training-b/b0220.wav
# Processing file: ./data/training_2016/training-b/b0221.wav
# Processing file: ./data/training_2016/training-b/b0222.wav
# Processing file: ./data/training_2016/training-b/b0223.wav
# Processing file: ./data/training_2016/training-b/b0224.wav
# Processing file: ./data/training_2016/training-b/b0225.wav
# Processing file: ./data/training_2016/training-b/b0226.wav
# Processing file: ./data/training_2016/training-b/b0227.wav
# Processing file: ./data/training_2016/training-b/b0228.wav
# Processing file: ./data/training_2016/training-b/b0229.wav
# Processing file: ./data/training_2016/training-b/b0230.wav
# Processing file: ./data/training_2016/training-b/b0231.wav
# Processing file: ./data/training_2016/training-b/b0232.wav
# Processing file: ./data/training_2016/training-b/b0233.wav
# Processing file: ./data/training_2016/training-b/b0234.wav
# Processing file: ./data/training_2016/training-b/b0235.wav
# Processing file: ./data/training_2016/training-b/b0236.wav
# Processing file: ./data/training_2016/training-b/b0237.wav
# Processing file: ./data/training_2016/training-b/b0238.wav
# Processing file: ./data/training_2016/training-b/b0239.wav
# Processing file: ./data/training_2016/training-b/b0240.wav
# Processing file: ./data/training_2016/training-b/b0241.wav
# Processing file: ./data/training_2016/training-b/b0242.wav
# Processing file: ./data/training_2016/training-b/b0243.wav
# Processing file: ./data/training_2016/training-b/b0244.wav
# Processing file: ./data/training_2016/training-b/b0245.wav
# Processing file: ./data/training_2016/training-b/b0246.wav
# Processing file: ./data/training_2016/training-b/b0247.wav
# Processing file: ./data/training_2016/training-b/b0248.wav
# Processing file: ./data/training_2016/training-b/b0249.wav
# Processing file: ./data/training_2016/training-b/b0250.wav
# Processing file: ./data/training_2016/training-b/b0251.wav
# Processing file: ./data/training_2016/training-b/b0252.wav
# Processing file: ./data/training_2016/training-b/b0253.wav
# Processing file: ./data/training_2016/training-b/b0254.wav
# Processing file: ./data/training_2016/training-b/b0255.wav
# Processing file: ./data/training_2016/training-b/b0256.wav
# Processing file: ./data/training_2016/training-b/b0257.wav
# Processing file: ./data/training_2016/training-b/b0258.wav
# Processing file: ./data/training_2016/training-b/b0259.wav
# Processing file: ./data/training_2016/training-b/b0260.wav
# Processing file: ./data/training_2016/training-b/b0261.wav
# Processing file: ./data/training_2016/training-b/b0262.wav
# Processing file: ./data/training_2016/training-b/b0263.wav
# Processing file: ./data/training_2016/training-b/b0264.wav
# Processing file: ./data/training_2016/training-b/b0265.wav
# Processing file: ./data/training_2016/training-b/b0266.wav
# Processing file: ./data/training_2016/training-b/b0267.wav
# Processing file: ./data/training_2016/training-b/b0268.wav
# Processing file: ./data/training_2016/training-b/b0269.wav
# Processing file: ./data/training_2016/training-b/b0270.wav
# Processing file: ./data/training_2016/training-b/b0271.wav
# Processing file: ./data/training_2016/training-b/b0272.wav
# Processing file: ./data/training_2016/training-b/b0273.wav
# Processing file: ./data/training_2016/training-b/b0274.wav
# Processing file: ./data/training_2016/training-b/b0275.wav
# Processing file: ./data/training_2016/training-b/b0276.wav
# Processing file: ./data/training_2016/training-b/b0277.wav
# Processing file: ./data/training_2016/training-b/b0278.wav
# Processing file: ./data/training_2016/training-b/b0279.wav
# Processing file: ./data/training_2016/training-b/b0280.wav
# Processing file: ./data/training_2016/training-b/b0281.wav
# Processing file: ./data/training_2016/training-b/b0282.wav
# Processing file: ./data/training_2016/training-b/b0283.wav
# Processing file: ./data/training_2016/training-b/b0284.wav
# Processing file: ./data/training_2016/training-b/b0285.wav
# Processing file: ./data/training_2016/training-b/b0286.wav
# Processing file: ./data/training_2016/training-b/b0287.wav
# Processing file: ./data/training_2016/training-b/b0288.wav
# Processing file: ./data/training_2016/training-b/b0289.wav
# Processing file: ./data/training_2016/training-b/b0290.wav
# Processing file: ./data/training_2016/training-b/b0291.wav
# Processing file: ./data/training_2016/training-b/b0292.wav
# Processing file: ./data/training_2016/training-b/b0293.wav
# Processing file: ./data/training_2016/training-b/b0294.wav
# Processing file: ./data/training_2016/training-b/b0295.wav
# Processing file: ./data/training_2016/training-b/b0296.wav
# Processing file: ./data/training_2016/training-b/b0297.wav
# Processing file: ./data/training_2016/training-b/b0298.wav
# Processing file: ./data/training_2016/training-b/b0299.wav
# Processing file: ./data/training_2016/training-b/b0300.wav
# Processing file: ./data/training_2016/training-b/b0301.wav
# Processing file: ./data/training_2016/training-b/b0302.wav
# Processing file: ./data/training_2016/training-b/b0303.wav
# Processing file: ./data/training_2016/training-b/b0304.wav
# Processing file: ./data/training_2016/training-b/b0305.wav
# Processing file: ./data/training_2016/training-b/b0306.wav
# Processing file: ./data/training_2016/training-b/b0307.wav
# Processing file: ./data/training_2016/training-b/b0308.wav
# Processing file: ./data/training_2016/training-b/b0309.wav
# Processing file: ./data/training_2016/training-b/b0310.wav
# Processing file: ./data/training_2016/training-b/b0311.wav
# Processing file: ./data/training_2016/training-b/b0312.wav
# Processing file: ./data/training_2016/training-b/b0313.wav
# Processing file: ./data/training_2016/training-b/b0314.wav
# Processing file: ./data/training_2016/training-b/b0315.wav
# Processing file: ./data/training_2016/training-b/b0316.wav
# Processing file: ./data/training_2016/training-b/b0317.wav
# Processing file: ./data/training_2016/training-b/b0318.wav
# Processing file: ./data/training_2016/training-b/b0319.wav
# Processing file: ./data/training_2016/training-b/b0320.wav
# Processing file: ./data/training_2016/training-b/b0321.wav
# Processing file: ./data/training_2016/training-b/b0322.wav
# Processing file: ./data/training_2016/training-b/b0323.wav
# Processing file: ./data/training_2016/training-b/b0324.wav
# Processing file: ./data/training_2016/training-b/b0325.wav
# Processing file: ./data/training_2016/training-b/b0326.wav
# Processing file: ./data/training_2016/training-b/b0327.wav
# Processing file: ./data/training_2016/training-b/b0328.wav
# Processing file: ./data/training_2016/training-b/b0329.wav
# Processing file: ./data/training_2016/training-b/b0330.wav
# Processing file: ./data/training_2016/training-b/b0331.wav
# Processing file: ./data/training_2016/training-b/b0332.wav
# Processing file: ./data/training_2016/training-b/b0333.wav
# Processing file: ./data/training_2016/training-b/b0334.wav
# Processing file: ./data/training_2016/training-b/b0335.wav
# Processing file: ./data/training_2016/training-b/b0336.wav
# Processing file: ./data/training_2016/training-b/b0337.wav
# Processing file: ./data/training_2016/training-b/b0338.wav
# Processing file: ./data/training_2016/training-b/b0339.wav
# Processing file: ./data/training_2016/training-b/b0340.wav
# Processing file: ./data/training_2016/training-b/b0341.wav
# Processing file: ./data/training_2016/training-b/b0342.wav
# Processing file: ./data/training_2016/training-b/b0343.wav
# Processing file: ./data/training_2016/training-b/b0344.wav
# Processing file: ./data/training_2016/training-b/b0345.wav
# Processing file: ./data/training_2016/training-b/b0346.wav
# Processing file: ./data/training_2016/training-b/b0347.wav
# Processing file: ./data/training_2016/training-b/b0348.wav
# Processing file: ./data/training_2016/training-b/b0349.wav
# Processing file: ./data/training_2016/training-b/b0350.wav
# Processing file: ./data/training_2016/training-b/b0351.wav
# Processing file: ./data/training_2016/training-b/b0352.wav
# Processing file: ./data/training_2016/training-b/b0353.wav
# Processing file: ./data/training_2016/training-b/b0354.wav
# Processing file: ./data/training_2016/training-b/b0355.wav
# Processing file: ./data/training_2016/training-b/b0356.wav
# Processing file: ./data/training_2016/training-b/b0357.wav
# Processing file: ./data/training_2016/training-b/b0358.wav
# Processing file: ./data/training_2016/training-b/b0359.wav
# Processing file: ./data/training_2016/training-b/b0360.wav
# Processing file: ./data/training_2016/training-b/b0361.wav
# Processing file: ./data/training_2016/training-b/b0362.wav
# Processing file: ./data/training_2016/training-b/b0363.wav
# Processing file: ./data/training_2016/training-b/b0364.wav
# Processing file: ./data/training_2016/training-b/b0365.wav
# Processing file: ./data/training_2016/training-b/b0366.wav
# Processing file: ./data/training_2016/training-b/b0367.wav
# Processing file: ./data/training_2016/training-b/b0368.wav
# Processing file: ./data/training_2016/training-b/b0369.wav
# Processing file: ./data/training_2016/training-b/b0370.wav
# Processing file: ./data/training_2016/training-b/b0371.wav
# Processing file: ./data/training_2016/training-b/b0372.wav
# Processing file: ./data/training_2016/training-b/b0373.wav
# Processing file: ./data/training_2016/training-b/b0374.wav
# Processing file: ./data/training_2016/training-b/b0375.wav
# Processing file: ./data/training_2016/training-b/b0376.wav
# Processing file: ./data/training_2016/training-b/b0377.wav
# Processing file: ./data/training_2016/training-b/b0378.wav
# Processing file: ./data/training_2016/training-b/b0379.wav
# Processing file: ./data/training_2016/training-b/b0380.wav
# Processing file: ./data/training_2016/training-b/b0381.wav
# Processing file: ./data/training_2016/training-b/b0382.wav
# Processing file: ./data/training_2016/training-b/b0383.wav
# Processing file: ./data/training_2016/training-b/b0384.wav
# Processing file: ./data/training_2016/training-b/b0385.wav
# Processing file: ./data/training_2016/training-b/b0386.wav
# Processing file: ./data/training_2016/training-b/b0387.wav
# Processing file: ./data/training_2016/training-b/b0388.wav
# Processing file: ./data/training_2016/training-b/b0389.wav
# Processing file: ./data/training_2016/training-b/b0390.wav
# Processing file: ./data/training_2016/training-b/b0391.wav
# Processing file: ./data/training_2016/training-b/b0392.wav
# Processing file: ./data/training_2016/training-b/b0393.wav
# Processing file: ./data/training_2016/training-b/b0394.wav
# Processing file: ./data/training_2016/training-b/b0395.wav
# Processing file: ./data/training_2016/training-b/b0396.wav
# Processing file: ./data/training_2016/training-b/b0397.wav
# Processing file: ./data/training_2016/training-b/b0398.wav
# Processing file: ./data/training_2016/training-b/b0399.wav
# Processing file: ./data/training_2016/training-b/b0400.wav
# Processing file: ./data/training_2016/training-b/b0401.wav
# Processing file: ./data/training_2016/training-b/b0402.wav
# Processing file: ./data/training_2016/training-b/b0403.wav
# Processing file: ./data/training_2016/training-b/b0404.wav
# ...
# Processing file: ./data/training_2016/training-e/e01988.wav
# Processing file: ./data/training_2016/training-e/e01989.wav
# Processing file: ./data/training_2016/training-e/e01990.wav
# Processing file: ./data/training_2016/training-e/e01991.wav
# Processing file: ./data/training_2016/training-e/e01992.wav
# Processing file: ./data/training_2016/training-e/e01993.wav
# Processing file: ./data/training_2016/training-e/e01994.wav
# Processing file: ./data/training_2016/training-e/e01995.wav
# Processing file: ./data/training_2016/training-e/e01996.wav
# Processing file: ./data/training_2016/training-e/e01997.wav
# Processing file: ./data/training_2016/training-e/e01998.wav
# Processing file: ./data/training_2016/training-e/e01999.wav
# Processing file: ./data/training_2016/training-e/e02000.wav
# Processing file: ./data/training_2016/training-e/e02001.wav
# Processing file: ./data/training_2016/training-e/e02002.wav
# Processing file: ./data/training_2016/training-e/e02003.wav
# Processing file: ./data/training_2016/training-e/e02004.wav
# Processing file: ./data/training_2016/training-e/e02005.wav
# Processing file: ./data/training_2016/training-e/e02006.wav
# Processing file: ./data/training_2016/training-e/e02007.wav
# Processing file: ./data/training_2016/training-e/e02008.wav
# Processing file: ./data/training_2016/training-e/e02009.wav
# Processing file: ./data/training_2016/training-e/e02010.wav
# Processing file: ./data/training_2016/training-e/e02011.wav
# Processing file: ./data/training_2016/training-e/e02012.wav
# Processing file: ./data/training_2016/training-e/e02013.wav
# Processing file: ./data/training_2016/training-e/e02014.wav
# Processing file: ./data/training_2016/training-e/e02015.wav
# Processing file: ./data/training_2016/training-e/e02016.wav
# Processing file: ./data/training_2016/training-e/e02017.wav
# Processing file: ./data/training_2016/training-e/e02018.wav
# Processing file: ./data/training_2016/training-e/e02019.wav
# Processing file: ./data/training_2016/training-e/e02020.wav
# Processing file: ./data/training_2016/training-e/e02021.wav
# Processing file: ./data/training_2016/training-e/e02022.wav
# Processing file: ./data/training_2016/training-e/e02023.wav
# Processing file: ./data/training_2016/training-e/e02024.wav
# Processing file: ./data/training_2016/training-e/e02025.wav
# Processing file: ./data/training_2016/training-e/e02026.wav
# Processing file: ./data/training_2016/training-e/e02027.wav
# Processing file: ./data/training_2016/training-e/e02028.wav
# Processing file: ./data/training_2016/training-e/e02029.wav
# Processing file: ./data/training_2016/training-e/e02030.wav
# Processing file: ./data/training_2016/training-e/e02031.wav
# Processing file: ./data/training_2016/training-e/e02032.wav
# Processing file: ./data/training_2016/training-e/e02033.wav
# Processing file: ./data/training_2016/training-e/e02034.wav
# Processing file: ./data/training_2016/training-e/e02035.wav
# Processing file: ./data/training_2016/training-e/e02036.wav
# Processing file: ./data/training_2016/training-e/e02037.wav
# Processing file: ./data/training_2016/training-e/e02038.wav
# Processing file: ./data/training_2016/training-e/e02039.wav
# Processing file: ./data/training_2016/training-e/e02040.wav
# Processing file: ./data/training_2016/training-e/e02041.wav
# Processing file: ./data/training_2016/training-e/e02042.wav
# Processing file: ./data/training_2016/training-e/e02043.wav
# Processing file: ./data/training_2016/training-e/e02044.wav
# Processing file: ./data/training_2016/training-e/e02045.wav
# Processing file: ./data/training_2016/training-e/e02046.wav
# Processing file: ./data/training_2016/training-e/e02047.wav
# Processing file: ./data/training_2016/training-e/e02048.wav
# Processing file: ./data/training_2016/training-e/e02049.wav
# Processing file: ./data/training_2016/training-e/e02050.wav
# Processing file: ./data/training_2016/training-e/e02051.wav
# Processing file: ./data/training_2016/training-e/e02052.wav
# Processing file: ./data/training_2016/training-e/e02053.wav
# Processing file: ./data/training_2016/training-e/e02054.wav
# Processing file: ./data/training_2016/training-e/e02055.wav
# Processing file: ./data/training_2016/training-e/e02056.wav
# Processing file: ./data/training_2016/training-e/e02057.wav
# Processing file: ./data/training_2016/training-e/e02058.wav
# Processing file: ./data/training_2016/training-e/e02059.wav
# Processing file: ./data/training_2016/training-e/e02060.wav
# Processing file: ./data/training_2016/training-e/e02061.wav
# Processing file: ./data/training_2016/training-e/e02062.wav
# Processing file: ./data/training_2016/training-e/e02063.wav
# Processing file: ./data/training_2016/training-e/e02064.wav
# Processing file: ./data/training_2016/training-e/e02065.wav
# Processing file: ./data/training_2016/training-e/e02066.wav
# Processing file: ./data/training_2016/training-e/e02067.wav
# Processing file: ./data/training_2016/training-e/e02068.wav
# Processing file: ./data/training_2016/training-e/e02069.wav
# Processing file: ./data/training_2016/training-e/e02070.wav
# Processing file: ./data/training_2016/training-e/e02071.wav
# Processing file: ./data/training_2016/training-e/e02072.wav
# Processing file: ./data/training_2016/training-e/e02073.wav
# Processing file: ./data/training_2016/training-e/e02074.wav
# Processing file: ./data/training_2016/training-e/e02075.wav
# Processing file: ./data/training_2016/training-e/e02076.wav
# Processing file: ./data/training_2016/training-e/e02077.wav
# Processing file: ./data/training_2016/training-e/e02078.wav
# Processing file: ./data/training_2016/training-e/e02079.wav
# Processing file: ./data/training_2016/training-e/e02080.wav
# Processing file: ./data/training_2016/training-e/e02081.wav
# Processing file: ./data/training_2016/training-e/e02082.wav
# Processing file: ./data/training_2016/training-e/e02083.wav
# Processing file: ./data/training_2016/training-e/e02084.wav
# Processing file: ./data/training_2016/training-e/e02085.wav
# Processing file: ./data/training_2016/training-e/e02086.wav
# Processing file: ./data/training_2016/training-e/e02087.wav
# Processing file: ./data/training_2016/training-e/e02088.wav
# Processing file: ./data/training_2016/training-e/e02089.wav
# Processing file: ./data/training_2016/training-e/e02090.wav
# Processing file: ./data/training_2016/training-e/e02091.wav
# Processing file: ./data/training_2016/training-e/e02092.wav
# Processing file: ./data/training_2016/training-e/e02093.wav
# Processing file: ./data/training_2016/training-e/e02094.wav
# Processing file: ./data/training_2016/training-e/e02095.wav
# Processing file: ./data/training_2016/training-e/e02096.wav
# Processing file: ./data/training_2016/training-e/e02097.wav
# Processing file: ./data/training_2016/training-e/e02098.wav
# Processing file: ./data/training_2016/training-e/e02099.wav
# Processing file: ./data/training_2016/training-e/e02100.wav
# Processing file: ./data/training_2016/training-e/e02101.wav
# Processing file: ./data/training_2016/training-e/e02102.wav
# Processing file: ./data/training_2016/training-e/e02103.wav
# Processing file: ./data/training_2016/training-e/e02104.wav
# Processing file: ./data/training_2016/training-e/e02105.wav
# Processing file: ./data/training_2016/training-e/e02106.wav
# Processing file: ./data/training_2016/training-e/e02107.wav
# Processing file: ./data/training_2016/training-e/e02108.wav
# Processing file: ./data/training_2016/training-e/e02109.wav
# Processing file: ./data/training_2016/training-e/e02110.wav
# Processing file: ./data/training_2016/training-e/e02111.wav
# Processing file: ./data/training_2016/training-e/e02112.wav
# Processing file: ./data/training_2016/training-e/e02113.wav
# Processing file: ./data/training_2016/training-e/e02114.wav
# Processing file: ./data/training_2016/training-e/e02115.wav
# Processing file: ./data/training_2016/training-e/e02116.wav
# Processing file: ./data/training_2016/training-e/e02117.wav
# Processing file: ./data/training_2016/training-e/e02118.wav
# Processing file: ./data/training_2016/training-e/e02119.wav
# Processing file: ./data/training_2016/training-e/e02120.wav
# Processing file: ./data/training_2016/training-e/e02121.wav
# Processing file: ./data/training_2016/training-e/e02122.wav
# Processing file: ./data/training_2016/training-e/e02123.wav
# Processing file: ./data/training_2016/training-e/e02124.wav
# Processing file: ./data/training_2016/training-e/e02125.wav
# Processing file: ./data/training_2016/training-e/e02126.wav
# Processing file: ./data/training_2016/training-e/e02127.wav
# Processing file: ./data/training_2016/training-e/e02128.wav
# Processing file: ./data/training_2016/training-e/e02129.wav
# Processing file: ./data/training_2016/training-e/e02130.wav
# Processing file: ./data/training_2016/training-e/e02131.wav
# Processing file: ./data/training_2016/training-e/e02132.wav
# Processing file: ./data/training_2016/training-e/e02133.wav
# Processing file: ./data/training_2016/training-e/e02134.wav
# Processing file: ./data/training_2016/training-e/e02135.wav
# Processing file: ./data/training_2016/training-e/e02136.wav
# Processing file: ./data/training_2016/training-e/e02137.wav
# Processing file: ./data/training_2016/training-e/e02138.wav
# Processing file: ./data/training_2016/training-e/e02139.wav
# Processing file: ./data/training_2016/training-e/e02140.wav
# Processing file: ./data/training_2016/training-e/e02141.wav
# Processing file: ./data/training_2016/training-f/f0001.wav
# Processing file: ./data/training_2016/training-f/f0002.wav
# Processing file: ./data/training_2016/training-f/f0003.wav
# Processing file: ./data/training_2016/training-f/f0004.wav
# Processing file: ./data/training_2016/training-f/f0005.wav
# Processing file: ./data/training_2016/training-f/f0006.wav
# Processing file: ./data/training_2016/training-f/f0007.wav
# Processing file: ./data/training_2016/training-f/f0008.wav
# Processing file: ./data/training_2016/training-f/f0009.wav
# Processing file: ./data/training_2016/training-f/f0010.wav
# Processing file: ./data/training_2016/training-f/f0011.wav
# Processing file: ./data/training_2016/training-f/f0012.wav
# Processing file: ./data/training_2016/training-f/f0013.wav
# Processing file: ./data/training_2016/training-f/f0014.wav
# Processing file: ./data/training_2016/training-f/f0015.wav
# Processing file: ./data/training_2016/training-f/f0016.wav
# Processing file: ./data/training_2016/training-f/f0017.wav
# Processing file: ./data/training_2016/training-f/f0018.wav
# Processing file: ./data/training_2016/training-f/f0019.wav
# Processing file: ./data/training_2016/training-f/f0020.wav
# Processing file: ./data/training_2016/training-f/f0021.wav
# Processing file: ./data/training_2016/training-f/f0022.wav
# Processing file: ./data/training_2016/training-f/f0023.wav
# Processing file: ./data/training_2016/training-f/f0024.wav
# Processing file: ./data/training_2016/training-f/f0025.wav
# Processing file: ./data/training_2016/training-f/f0026.wav
# Processing file: ./data/training_2016/training-f/f0027.wav
# Processing file: ./data/training_2016/training-f/f0028.wav
# Processing file: ./data/training_2016/training-f/f0029.wav
# Processing file: ./data/training_2016/training-f/f0030.wav
# Processing file: ./data/training_2016/training-f/f0031.wav
# Processing file: ./data/training_2016/training-f/f0032.wav
# Processing file: ./data/training_2016/training-f/f0033.wav
# Processing file: ./data/training_2016/training-f/f0034.wav
# Processing file: ./data/training_2016/training-f/f0035.wav
# Processing file: ./data/training_2016/training-f/f0036.wav
# Processing file: ./data/training_2016/training-f/f0037.wav
# Processing file: ./data/training_2016/training-f/f0038.wav
# Processing file: ./data/training_2016/training-f/f0039.wav
# Processing file: ./data/training_2016/training-f/f0040.wav
# Processing file: ./data/training_2016/training-f/f0041.wav
# Processing file: ./data/training_2016/training-f/f0042.wav
# Processing file: ./data/training_2016/training-f/f0043.wav
# Processing file: ./data/training_2016/training-f/f0044.wav
# Processing file: ./data/training_2016/training-f/f0045.wav
# Processing file: ./data/training_2016/training-f/f0046.wav
# Processing file: ./data/training_2016/training-f/f0047.wav
# Processing file: ./data/training_2016/training-f/f0048.wav
# Processing file: ./data/training_2016/training-f/f0049.wav
# Processing file: ./data/training_2016/training-f/f0050.wav
# Processing file: ./data/training_2016/training-f/f0051.wav
# Processing file: ./data/training_2016/training-f/f0052.wav
# Processing file: ./data/training_2016/training-f/f0053.wav
# Processing file: ./data/training_2016/training-f/f0054.wav
# Processing file: ./data/training_2016/training-f/f0055.wav
# Processing file: ./data/training_2016/training-f/f0056.wav
# Processing file: ./data/training_2016/training-f/f0057.wav
# Processing file: ./data/training_2016/training-f/f0058.wav
# Processing file: ./data/training_2016/training-f/f0059.wav
# Processing file: ./data/training_2016/training-f/f0060.wav
# Processing file: ./data/training_2016/training-f/f0061.wav
# Processing file: ./data/training_2016/training-f/f0062.wav
# Processing file: ./data/training_2016/training-f/f0063.wav
# Processing file: ./data/training_2016/training-f/f0064.wav
# Processing file: ./data/training_2016/training-f/f0065.wav
# Processing file: ./data/training_2016/training-f/f0066.wav
# Processing file: ./data/training_2016/training-f/f0067.wav
# Processing file: ./data/training_2016/training-f/f0068.wav
# Processing file: ./data/training_2016/training-f/f0069.wav
# Processing file: ./data/training_2016/training-f/f0070.wav
# Processing file: ./data/training_2016/training-f/f0071.wav
# Processing file: ./data/training_2016/training-f/f0072.wav
# Processing file: ./data/training_2016/training-f/f0073.wav
# Processing file: ./data/training_2016/training-f/f0074.wav
# Processing file: ./data/training_2016/training-f/f0075.wav
# Processing file: ./data/training_2016/training-f/f0076.wav
# Processing file: ./data/training_2016/training-f/f0077.wav
# Processing file: ./data/training_2016/training-f/f0078.wav
# Processing file: ./data/training_2016/training-f/f0079.wav
# Processing file: ./data/training_2016/training-f/f0080.wav
# Processing file: ./data/training_2016/training-f/f0081.wav
# Processing file: ./data/training_2016/training-f/f0082.wav
# Processing file: ./data/training_2016/training-f/f0083.wav
# Processing file: ./data/training_2016/training-f/f0084.wav
# Processing file: ./data/training_2016/training-f/f0085.wav
# Processing file: ./data/training_2016/training-f/f0086.wav
# Processing file: ./data/training_2016/training-f/f0087.wav
# Processing file: ./data/training_2016/training-f/f0088.wav
# Processing file: ./data/training_2016/training-f/f0089.wav
# Processing file: ./data/training_2016/training-f/f0090.wav
# Processing file: ./data/training_2016/training-f/f0091.wav
# Processing file: ./data/training_2016/training-f/f0092.wav
# Processing file: ./data/training_2016/training-f/f0093.wav
# Processing file: ./data/training_2016/training-f/f0094.wav
# Processing file: ./data/training_2016/training-f/f0095.wav
# Processing file: ./data/training_2016/training-f/f0096.wav
# Processing file: ./data/training_2016/training-f/f0097.wav
# Processing file: ./data/training_2016/training-f/f0098.wav
# Processing file: ./data/training_2016/training-f/f0099.wav
# Processing file: ./data/training_2016/training-f/f0100.wav
# Processing file: ./data/training_2016/training-f/f0101.wav
# Processing file: ./data/training_2016/training-f/f0102.wav
# Processing file: ./data/training_2016/training-f/f0103.wav
# Processing file: ./data/training_2016/training-f/f0104.wav
# Processing file: ./data/training_2016/training-f/f0105.wav
# Processing file: ./data/training_2016/training-f/f0106.wav
# Processing file: ./data/training_2016/training-f/f0107.wav
# Processing file: ./data/training_2016/training-f/f0108.wav
# Processing file: ./data/training_2016/training-f/f0109.wav
# Processing file: ./data/training_2016/training-f/f0110.wav
# Processing file: ./data/training_2016/training-f/f0111.wav
# Processing file: ./data/training_2016/training-f/f0112.wav
# Processing file: ./data/training_2016/training-f/f0113.wav
# Processing file: ./data/training_2016/training-f/f0114.wav

# %%
# Save combined features and labels for future use
np.save('mfcc_features.npy', all_mfccs)
np.save('labels.npy', all_labels)

# %%
print(all_mfccs[1])
print(all_labels[1])
# Out:
# [-268.50842 -218.85399 -224.99608 ...    0.         0.         0.     ]
# 1

# %%
def normalize_mfcc(mfcc):
    """Normalize MFCC values to the range [0, 255] for image representation."""
    mfcc_min = np.min(mfcc)
    mfcc_max = np.max(mfcc)
    
    if mfcc_max - mfcc_min == 0:
        # If max and min are the same, return an array of zeros (avoid division by zero)
        return np.zeros_like(mfcc)
    
    return 255 * (mfcc - mfcc_min) / (mfcc_max - mfcc_min)

# %%
def mfcc_to_rgb(mfcc, target_size=(224, 224)):
    """Convert MFCC to RGB image representation."""
    # Normalize MFCC values
    mfcc_normalized = normalize_mfcc(mfcc)
    
    # Resize the MFCC to the desired target size
    resized_mfcc = cv2.resize(mfcc_normalized, target_size, interpolation=cv2.INTER_LINEAR)
    
    # Convert single-channel to 3-channel by replicating across R, G, and B
    rgb_image = np.stack([resized_mfcc] * 3, axis=-1).astype(np.uint8)
    
    return rgb_image

# %%
def reshape_mfcc_features(all_mfccs, n_mfcc=13):
    """Reshape the flattened MFCC features into a 3D array (samples, n_mfcc, time_steps)."""
    num_samples = all_mfccs.shape[0]
    flattened_dim = all_mfccs.shape[1]
    
    # Calculate the number of time steps
    time_steps = flattened_dim // n_mfcc
    if flattened_dim % n_mfcc != 0:
        raise ValueError(f"Inconsistent dimensions: Cannot reshape {flattened_dim} into (13, time_steps).")
    
    return all_mfccs.reshape((num_samples, n_mfcc, time_steps))

# %%
def display_images(mfcc_features, num_images=3, target_size=(224, 224)):
    """Display a few MFCC features as RGB images."""
    plt.figure(figsize=(15, 5))
    
    for i in range(num_images):
        mfcc = mfcc_features[i]  # Extract individual MFCC sample
        rgb_image = mfcc_to_rgb(mfcc, target_size)
        
        # Plot the RGB image
        plt.subplot(1, num_images, i + 1)
        plt.imshow(rgb_image)
        plt.title(f"MFCC Sample {i + 1}")
        plt.axis('off')
    
    plt.show()

# %%
try:
    # Parameters
    n_mfcc = 13  # Number of MFCC coefficients per time step
    num_samples = all_mfccs.shape[0]
    
    # Reshape MFCCs to 2D array (samples, n_mfcc, time_steps)
    all_mfccs_reshaped = reshape_mfcc_features(all_mfccs, n_mfcc)

    # Display 2-3 images from the dataset
    display_images(all_mfccs_reshaped, num_images=3, target_size=(224, 224))

except Exception as e:
    print(f"Error processing MFCC features: {e}")

# %%
def extract_mel_spectrogram(file_path, fixed_length=130, n_mels=128):
    """Extract Mel Spectrogram from an audio file."""
    try:
        y, sr = librosa.load(file_path, sr=None)
        mel_spec = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels)
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)

        # Pad or truncate to the fixed length
        if mel_spec_db.shape[1] < fixed_length:
            padding = fixed_length - mel_spec_db.shape[1]
            mel_spec_db = np.pad(mel_spec_db, ((0, 0), (0, padding)), mode='constant')
        else:
            mel_spec_db = mel_spec_db[:, :fixed_length]
    except Exception as e:
        raise ValueError(f"Error processing file {file_path}: {e}")
    
    return mel_spec_db

# %%
def read_dataset_with_labels(data_path, reference_path, fixed_length=130, n_mels=128):
    """Read the dataset and extract Mel Spectrograms along with corresponding labels."""
    mel_specs = []
    labels = []
    
    # Load reference CSV to get labels
    reference_df = load_reference_file(reference_path)
    
    # Process all audio files in the folder
    file_list = sorted(os.listdir(data_path))
    
    for file in file_list:
        if file.endswith('.wav'):
            file_path = os.path.join(data_path, file)
            try:
                mel_spec_db = extract_mel_spectrogram(file_path, fixed_length, n_mels)
                mel_specs.append(mel_spec_db)
                if file in reference_df.index:
                    label = reference_df.loc[file, 'label']
                    labels.append(label)
                else:
                    print(f"Warning: Label for {file} not found. Skipping.")
            except Exception as e:
                print(f"Error with file {file}: {e}")
    
    # Ensure there are no missing Mel Spectrograms
    if not mel_specs:
        raise ValueError("No valid Mel Spectrogram data found. Please check the dataset.")

    return np.array(mel_specs), np.array(labels)

# %%
def process_all_folders(base_path, folders):
    """Process all folders, extracting Mel Spectrograms and labels."""
    all_mel_specs = []
    all_labels = []

    for folder in folders:
        data_path = os.path.join(base_path, folder)
        reference_path = os.path.join(data_path, 'REFERENCE.csv')

        try:
            folder_mel_specs, folder_labels = read_dataset_with_labels(data_path, reference_path)
            all_mel_specs.extend(folder_mel_specs)
            all_labels.extend(folder_labels)
        except Exception as e:
            print(f"Error processing folder {folder}: {e}")
    
    return np.array(all_mel_specs), np.array(all_labels)

# %%
try:
        # Process all folders
        all_mel_specs, all_labels = process_all_folders(base_path, folders)

        # Check the shapes of the combined data
        print(f"Total Mel Spectrogram shape: {all_mel_specs.shape}, Total Labels shape: {all_labels.shape}")

        # Save combined features and labels for future use
        np.save('mel_spectrogram_features.npy', all_mel_specs)
        np.save('labels.npy', all_labels)
        
except Exception as e:
        print(f"Error during dataset processing: {e}")
# Out:
# Total Mel Spectrogram shape: (3240, 128, 130), Total Labels shape: (3240,)

# %%
def display_mel_spectrograms(mel_specs, num_images=3):
    """Display Mel Spectrograms with a default color map."""
    plt.figure(figsize=(15, 5))
    for i in range(num_images):
        mel_spec = mel_specs[i]
        plt.subplot(1, num_images, i + 1)
        plt.imshow(mel_spec, aspect='auto', origin='lower', cmap='viridis')
        plt.title(f"Mel Spectrogram {i + 1}")
        plt.axis('off')
    plt.show()

# %%
def display_log_mel_spectrograms(mel_specs, num_images=3):
    """Display Mel Spectrograms with log scaling."""
    plt.figure(figsize=(15, 5))
    for i in range(num_images):
        mel_spec = mel_specs[i]
        mel_spec_log = np.log1p(mel_spec)  # Apply log scaling
        plt.subplot(1, num_images, i + 1)
        plt.imshow(mel_spec_log, aspect='auto', origin='lower', cmap='inferno')
        plt.title(f"Log-scaled Mel Spectrogram {i + 1}")
        plt.axis('off')
    plt.show()

# %%
def display_average_mel_spectrogram(mel_specs):
    """Display the average Mel Spectrogram across all samples."""
    avg_mel_spec = np.mean(mel_specs, axis=0)
    plt.figure(figsize=(8, 6))
    plt.imshow(avg_mel_spec, aspect='auto', origin='lower', cmap='viridis')
    plt.title("Average Mel Spectrogram")
    plt.colorbar(format="%+2.0f dB")
    plt.axis('off')
    plt.show()

# %%
def display_top_mel_spectrograms(mel_specs, top_n=5):
    """Display top N Mel Spectrograms based on energy."""
    energies = [np.sum(mel_spec) for mel_spec in mel_specs]  # Total energy in each Mel spectrogram
    top_indices = np.argsort(energies)[-top_n:]  # Indices of the top N spectrograms by energy
    
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(top_indices):
        mel_spec = mel_specs[idx]
        plt.subplot(1, top_n, i + 1)
        plt.imshow(mel_spec, aspect='auto', origin='lower', cmap='viridis')
        plt.title(f"Top Mel Spectrogram {i + 1}")
        plt.axis('off')
    plt.show()

# %%
# Display 2-3 Mel Spectrograms (original)
display_mel_spectrograms(all_mel_specs, num_images=3)

# %%
# Display log-scaled Mel Spectrograms
display_log_mel_spectrograms(all_mel_specs, num_images=3)
# Out:
# /var/folders/f6/q3w6f44s5jvc8vq247_z0l7c0000gn/T/ipykernel_17040/2182027507.py:6: RuntimeWarning: invalid value encountered in log1p
#   mel_spec_log = np.log1p(mel_spec)  # Apply log scaling

# %%
# Display the average Mel Spectrogram across all samples
display_average_mel_spectrogram(all_mel_specs)

# %%
# Display the top 5 Mel Spectrograms based on energy
display_top_mel_spectrograms(all_mel_specs, top_n=5)

# %%
def display_energy_distribution(mel_specs):
    """Display the distribution of energy across Mel Spectrograms."""
    energies = [np.sum(mel_spec) for mel_spec in mel_specs]  # Total energy in each Mel spectrogram
    plt.figure(figsize=(8, 6))
    plt.hist(energies, bins=50, color='blue', alpha=0.7)
    plt.title("Energy Distribution Across Mel Spectrograms")
    plt.xlabel("Energy")
    plt.ylabel("Frequency")
    plt.show()

# %%
def display_pca_mel_spectrograms(mel_specs, n_components=2):
    """Display PCA components of Mel Spectrograms."""
    mel_specs_flattened = mel_specs.reshape(mel_specs.shape[0], -1)  # Flatten spectrograms into vectors
    pca = PCA(n_components=n_components)
    pca_components = pca.fit_transform(mel_specs_flattened)
    
    plt.figure(figsize=(8, 6))
    plt.scatter(pca_components[:, 0], pca_components[:, 1], c='blue', alpha=0.7)
    plt.title(f"PCA of Mel Spectrograms (First {n_components} Components)")
    plt.xlabel("Principal Component 1")
    plt.ylabel("Principal Component 2")
    plt.show()

# %%
def display_normalized_vs_unnormalized(mel_specs, num_images=3):
    """Display comparison of normalized and unnormalized Mel Spectrograms."""
    plt.figure(figsize=(15, 5))
    for i in range(num_images):
        mel_spec = mel_specs[i]
        
        # Normalized version
        mel_spec_normalized = (mel_spec - np.min(mel_spec)) / (np.max(mel_spec) - np.min(mel_spec))
        
        # Plot Unnormalized
        plt.subplot(2, num_images, i + 1)
        plt.imshow(mel_spec, aspect='auto', origin='lower', cmap='viridis')
        plt.title(f"Unnormalized {i + 1}")
        plt.axis('off')
        
        # Plot Normalized
        plt.subplot(2, num_images, i + num_images + 1)
        plt.imshow(mel_spec_normalized, aspect='auto', origin='lower', cmap='viridis')
        plt.title(f"Normalized {i + 1}")
        plt.axis('off')
            
    plt.tight_layout()
    plt.show()

# %%
def display_mean_frequency_distribution(mel_specs, sr=22050):
    """Display the distribution of mean frequencies across the Mel Spectrograms."""
    mean_frequencies = []
    for mel_spec in mel_specs:
        # Get Mel frequencies corresponding to each Mel frequency bin
        freq_axis = librosa.mel_frequencies(n_mels=mel_spec.shape[0], fmin=0, fmax=sr / 2)
        
        # Calculate the weighted mean frequency across all time frames
        weighted_frequencies = np.dot(mel_spec.T, freq_axis)  # T to align dimensions (130, 128) -> (130,)
        mean_frequency = np.mean(weighted_frequencies)  # Average frequency across all time steps
        
        mean_frequencies.append(mean_frequency)
    
    plt.figure(figsize=(8, 6))
    plt.hist(mean_frequencies, bins=50, color='green', alpha=0.7)
    plt.title("Distribution of Mean Frequencies Across Mel Spectrograms")
    plt.xlabel("Mean Frequency (Hz)")
    plt.ylabel("Frequency")
    plt.show()

# %%
# Display the energy distribution across Mel Spectrograms
display_energy_distribution(all_mel_specs)

# %%
# Display the PCA of Mel Spectrograms (2 components)
display_pca_mel_spectrograms(all_mel_specs)

# %%
# Display normalized vs unnormalized Mel Spectrograms (2-3 samples)
display_normalized_vs_unnormalized(all_mel_specs, num_images=3)

# %%
# Display the distribution of mean frequencies across Mel Spectrograms
display_mean_frequency_distribution(all_mel_specs)

# %%
# Constants for audio processing
SAMPLE_RATE = 22050
DURATION = 2  # Duration in seconds
N_MELS = 64
N_FFT = 2048
HOP_LENGTH = 512
FIXED_LENGTH = 87  # Fixed time frames after padding/truncation

# %%
# Function to load and preprocess audio into mel spectrogram
def load_and_preprocess_audio(file_path):
    audio, _ = librosa.load(file_path, sr=SAMPLE_RATE, duration=DURATION)
    if len(audio) < SAMPLE_RATE * DURATION:
        audio = np.pad(audio, (0, SAMPLE_RATE * DURATION - len(audio)))
    else:
        audio = audio[:SAMPLE_RATE * DURATION]
    mel_spec = librosa.feature.melspectrogram(y=audio, sr=SAMPLE_RATE, n_mels=N_MELS, n_fft=N_FFT, hop_length=HOP_LENGTH)
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)  # Convert to decibels
    return mel_spec_db

# %%
# Data augmentation function
def augment_audio(audio, sr=SAMPLE_RATE, augment_prob=0.5):
    if np.random.random() < augment_prob:
        stretch_factor = np.random.uniform(0.8, 1.2)
        audio = librosa.effects.time_stretch(audio, rate=stretch_factor)

    if np.random.random() < augment_prob:
        n_steps = np.random.randint(-4, 5)
        audio = librosa.effects.pitch_shift(audio, sr=sr, n_steps=n_steps)

    if np.random.random() < augment_prob:
        noise_factor = np.random.uniform(0.005, 0.02)
        noise = np.random.randn(len(audio))
        audio = audio + noise_factor * noise
    
    if np.random.random() < augment_prob:
        gain_factor = np.random.uniform(0.8, 1.2)
        audio = audio * gain_factor

    target_length = sr * DURATION
    if len(audio) > target_length:
        start = np.random.randint(0, len(audio) - target_length)
        audio = audio[start:start + target_length]
    elif len(audio) < target_length:
        audio = np.pad(audio, (0, target_length - len(audio)))

    audio = np.clip(audio, -1, 1)
    return audio

# %%
# PyTorch Dataset for Heart Sound Classification
class HeartSoundDataset(Dataset):
    def __init__(self, file_paths, labels, augment=False, fixed_length=FIXED_LENGTH):
        self.file_paths = file_paths
        self.labels = labels
        self.augment = augment
        self.fixed_length = fixed_length
        
    def __len__(self):
        return len(self.file_paths)
    
    def __getitem__(self, idx):
        # Load the audio file
        audio, sr = librosa.load(self.file_paths[idx], sr=SAMPLE_RATE, duration=DURATION)

        # Apply augmentation if enabled
        if self.augment:
            audio = augment_audio(audio, sr=SAMPLE_RATE, augment_prob=0.5)

        # Generate mel spectrogram
        mel_spec = librosa.feature.melspectrogram(y=audio, sr=sr, n_mels=N_MELS, n_fft=N_FFT, hop_length=HOP_LENGTH)
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)

        # Normalize the spectrogram
        mel_spec_db = (mel_spec_db - mel_spec_db.min()) / (mel_spec_db.max() - mel_spec_db.min())

        # Debugging: print the shape of the mel spectrogram
        # print(f"Mel spectrogram shape: {mel_spec_db.shape}")
        
        # Pad or truncate the spectrogram to the fixed length
        if mel_spec_db.shape[1] < self.fixed_length:
            pad_width = self.fixed_length - mel_spec_db.shape[1]
            mel_spec_db = np.pad(mel_spec_db, ((0, 0), (0, pad_width)), mode='constant')
        else:
            mel_spec_db = mel_spec_db[:, :self.fixed_length]

        label = self.labels[idx]
        return torch.FloatTensor(mel_spec_db).unsqueeze(0), torch.tensor(label)

# %%
# Collate function for batching
def collate_fn(batch):
    specs, labels = zip(*batch)
    specs = torch.stack(specs)
    labels = torch.stack(labels)
    return specs, labels

# %%
# Helper function to remap labels
def remap_labels(labels):
    return [0 if label == -1 else label for label in labels]

# %%
# Function to prepare dataset and labels
def prepare_dataset(data_path, reference_path):
    file_paths = []
    labels = []

    reference_df = pd.read_csv(reference_path, header=None)
    reference_df.columns = ['filename', 'label']
    reference_df['filename'] += '.wav'  # Append '.wav' to match audio files

    for file in sorted(os.listdir(data_path)):
        if file.endswith('.wav'):
            file_path = os.path.join(data_path, file)
            if file in reference_df['filename'].values:
                file_paths.append(file_path)
                label = reference_df.loc[reference_df['filename'] == file, 'label'].values[0]
                labels.append(int(label))
    labels = remap_labels(labels)
    return file_paths, labels

# %%
try:
    # Specify base path and dataset folders
    base_path = './data/training_2016'
    
    train_folders = ['training-a', 'training-b', 'training-c', 'training-d', 'training-e', 'training-f']
    validation_folder = 'validation'
    # Initialize lists to store file paths and labels for training and validation
    train_file_paths, train_labels = [], []
    val_file_paths, val_labels = [], []

    # Process training folders
    for folder in train_folders:
        data_path = os.path.join(base_path, folder)
        reference_path = os.path.join(data_path, 'REFERENCE.csv')
        file_paths, labels = prepare_dataset(data_path, reference_path)
        train_file_paths.extend(file_paths)
        train_labels.extend(labels)

    # Process validation folder
    validation_data_path = os.path.join(base_path, validation_folder)
    validation_reference_path = os.path.join(validation_data_path, 'REFERENCE.csv')
    val_file_paths, val_labels = prepare_dataset(validation_data_path, validation_reference_path)

    # Create Dataset instances for training and validation
    train_dataset = HeartSoundDataset(train_file_paths, train_labels, augment=True)
    val_dataset = HeartSoundDataset(val_file_paths, val_labels, augment=False)
    print("training: ", train_dataset[0])
    print("val_dataset: ", val_dataset.fixed_length)
    # Initialize DataLoader instances for batching and shuffling
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=collate_fn)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, collate_fn=collate_fn)
    # Output dataset information
    print(f"Train Dataset: {len(train_dataset)} samples")
    print(f"Validation Dataset: {len(val_dataset)} samples")
    print(train_dataset[0])
    print(train_dataset[8]);
    
except Exception as e:
    print(f"Error processing {file_path}: {e}")
# Out:
# Mel spectrogram shape: (64, 87)
# training:  (tensor([[[0.8147, 0.8329, 0.8317,  ..., 0.7458, 0.7033, 0.6292],
#          [0.6743, 0.6620, 0.6606,  ..., 0.6255, 0.6337, 0.6131],
#          [0.5826, 0.5579, 0.5873,  ..., 0.5532, 0.5766, 0.5623],
#          ...,
#          [0.1690, 0.0936, 0.0000,  ..., 0.0000, 0.0000, 0.0055],
#          [0.1674, 0.0920, 0.0000,  ..., 0.0000, 0.0000, 0.0039],
#          [0.1665, 0.0910, 0.0000,  ..., 0.0000, 0.0000, 0.0029]]]), tensor(1))
# val_dataset:  87
# Train Dataset: 3240 samples
# Validation Dataset: 301 samples
# Mel spectrogram shape: (64, 87)
# (tensor([[[0.5653, 0.6550, 0.6561,  ..., 0.5717, 0.5367, 0.4697],
#          [0.2842, 0.3094, 0.3347,  ..., 0.3012, 0.3588, 0.2995],
#          [0.1654, 0.2606, 0.2344,  ..., 0.1502, 0.1925, 0.2285],
#          ...,
#          [0.1527, 0.1801, 0.1867,  ..., 0.2199, 0.1895, 0.1464],
#          [0.1692, 0.2110, 0.2123,  ..., 0.2239, 0.2097, 0.1535],
#          [0.1561, 0.2051, 0.2214,  ..., 0.2084, 0.2308, 0.1764]]]), tensor(1))
# Mel spectrogram shape: (64, 87)
# (tensor([[[0.8806, 0.9087, 0.9208,  ..., 0.7828, 0.7773, 0.6747],
#          [0.8095, 0.8356, 0.8704,  ..., 0.6925, 0.6801, 0.5832],
#          [0.7624, 0.7303, 0.7089,  ..., 0.4735, 0.4768, 0.4644],
#          ...,
#          [0.3034, 0.2280, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.3019, 0.2265, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.3009, 0.2255, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]]), tensor(0))

# %%
# Define the CNN model with transfer learning using MobileNetV2
class HeartSoundNet(nn.Module):
    def __init__(self, num_classes):
        super(HeartSoundNet, self).__init__()
        
        # Load a pre-trained MobileNetV2 model
        self.mobilenetv2 = models.mobilenet_v2(pretrained=True)
        
        # Modify the first convolutional layer to accept 1-channel input (grayscale)
        self.mobilenetv2.features[0][0] = nn.Conv2d(1, 32, kernel_size=3, stride=2, padding=1, bias=False)
        
        # Use the feature extractor part of MobileNetV2 (removes the classifier part)
        self.feature_extractor = self.mobilenetv2.features
                # Add custom classification layers
        self.fc1 = nn.Linear(1280, 512)  # Fully connected layer after feature extraction
        self.batch_norm = nn.BatchNorm1d(512)  # Batch normalization
        self.fc2 = nn.Linear(512, num_classes)  # Final classification layer

    def forward(self, x):
        x = self.feature_extractor(x)  # Extract features using MobileNetV2
        x = x.mean([2, 3])  # Global average pooling to reduce the spatial dimensions
        x = F.relu(self.fc1(x))
        x = self.batch_norm(x)  # Apply batch normalization
        x = self.fc2(x)
        return x

# %%
# Training function with Early Stopping
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, scheduler=None, early_stopping_patience=10):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    best_val_loss = float('inf')
    patience_counter = 0  # Tracks epochs without improvement
    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []
    
    for epoch in range(num_epochs):
        # Training phase
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        for inputs, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} - Training"):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = correct / total
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)
        
        # Validation phase
        model.eval()
        val_running_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_running_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        val_loss = val_running_loss / len(val_loader.dataset)
        val_acc = val_correct / val_total
        val_losses.append(val_loss)
        val_accuracies.append(val_acc)
        
        if scheduler:
            scheduler.step(val_acc)
            
        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}, "
              f"Train Acc: {epoch_acc:.4f}, Val Acc: {val_acc:.4f}")

        # Early Stopping logic
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), "best_model.pth")
            print(f"New best model saved with validation loss: {val_loss:.4f}")
            patience_counter = 0  # Reset the counter if validation loss improves
        else:
            patience_counter += 1
            if patience_counter >= early_stopping_patience:
                print("Early stopping triggered!")
                break
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# %%
# Function to plot the training/validation losses and accuracies
def plot_training_history(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, len(train_losses) + 1)
    
    # Plot Losses
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')
    
    # Plot Accuracies
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')
    
    plt.tight_layout()
    plt.show()

# %%
# Model setup and training
num_classes = 2  # Adjust based on your dataset (e.g., normal vs. abnormal heart sounds)
learning_rate = 0.0001
num_epochs = 40
early_stopping_patience = 10  # Stop training if no improvement for 10 epochs

# Initialize the model
model = HeartSoundNet(num_classes=num_classes)

# Optionally, calculate class weights for imbalanced classes
# Uncomment and adjust based on dataset distribution if needed:
# class_weights = torch.tensor([weight_class_0, weight_class_1], dtype=torch.float).to(device)
# criterion = nn.CrossEntropyLoss(weight=class_weights)

# For now, we will use CrossEntropyLoss without class weights
criterion = nn.CrossEntropyLoss()

# Define the optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Using StepLR scheduler (decay learning rate every 5 epochs by a factor of 0.1)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# Assuming `train_loader` and `val_loader` are already defined
trained_model, train_losses, val_losses, train_acc, val_acc = train_model(
    model, 
    train_loader, 
    val_loader, 
    criterion, 
    optimizer, 
    num_epochs, 
    scheduler, 
    early_stopping_patience=early_stopping_patience  # Add early stopping
)

# Save the trained model after training
torch.save(trained_model.state_dict(), 'heart_sound_model.pth')

# Plot the training and validation losses/accuracies
plot_training_history(train_losses, val_losses, train_acc, val_acc)
# Out:
# /Users/yanxu/miniconda3/envs/heartSound/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/yanxu/miniconda3/envs/heartSound/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /Users/yanxu/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100.0%
# Epoch 1/40 - Training:   0%|          | 0/102 [00:00<?, ?it/s]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:   1%|          | 1/102 [00:01<02:02,  1.22s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:   2%|▏         | 2/102 [00:02<01:56,  1.17s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:   3%|▎         | 3/102 [00:03<01:53,  1.15s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:   4%|▍         | 4/102 [00:04<01:56,  1.19s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:   5%|▍         | 5/102 [00:06<01:58,  1.22s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:   6%|▌         | 6/102 [00:07<01:56,  1.22s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:   7%|▋         | 7/102 [00:08<01:53,  1.20s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:   8%|▊         | 8/102 [00:09<01:52,  1.20s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:   9%|▉         | 9/102 [00:10<01:48,  1.16s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  10%|▉         | 10/102 [00:11<01:46,  1.16s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  11%|█         | 11/102 [00:13<01:47,  1.18s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  12%|█▏        | 12/102 [00:14<01:47,  1.20s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  13%|█▎        | 13/102 [00:15<01:45,  1.19s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  14%|█▎        | 14/102 [00:16<01:45,  1.20s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  15%|█▍        | 15/102 [00:17<01:45,  1.21s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  16%|█▌        | 16/102 [00:19<01:43,  1.21s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  17%|█▋        | 17/102 [00:20<01:41,  1.19s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  18%|█▊        | 18/102 [00:21<01:40,  1.20s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  19%|█▊        | 19/102 [00:22<01:39,  1.20s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  20%|█▉        | 20/102 [00:23<01:37,  1.19s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  21%|██        | 21/102 [00:25<01:37,  1.21s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  22%|██▏       | 22/102 [00:26<01:35,  1.19s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  23%|██▎       | 23/102 [00:27<01:45,  1.33s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  24%|██▎       | 24/102 [00:29<01:42,  1.31s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  25%|██▍       | 25/102 [00:30<01:37,  1.26s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  25%|██▌       | 26/102 [00:31<01:34,  1.24s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  26%|██▋       | 27/102 [00:32<01:31,  1.21s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  27%|██▋       | 28/102 [00:33<01:29,  1.20s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  28%|██▊       | 29/102 [00:35<01:27,  1.20s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  29%|██▉       | 30/102 [00:36<01:25,  1.19s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  30%|███       | 31/102 [00:37<01:24,  1.18s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  31%|███▏      | 32/102 [00:38<01:21,  1.16s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  32%|███▏      | 33/102 [00:39<01:21,  1.19s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  33%|███▎      | 34/102 [00:40<01:19,  1.17s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  34%|███▍      | 35/102 [00:42<01:20,  1.20s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  35%|███▌      | 36/102 [00:43<01:19,  1.20s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  36%|███▋      | 37/102 [00:44<01:17,  1.19s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  37%|███▋      | 38/102 [00:45<01:15,  1.18s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  38%|███▊      | 39/102 [00:46<01:12,  1.15s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  39%|███▉      | 40/102 [00:47<01:12,  1.17s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  40%|████      | 41/102 [00:49<01:11,  1.17s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  41%|████      | 42/102 [00:50<01:09,  1.17s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# ...
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  64%|██████▎   | 65/102 [01:17<00:43,  1.18s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  65%|██████▍   | 66/102 [01:18<00:42,  1.18s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  66%|██████▌   | 67/102 [01:19<00:42,  1.22s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  67%|██████▋   | 68/102 [01:20<00:40,  1.19s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  68%|██████▊   | 69/102 [01:22<00:39,  1.19s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  69%|██████▊   | 70/102 [01:23<00:37,  1.17s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  70%|██████▉   | 71/102 [01:24<00:36,  1.18s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  71%|███████   | 72/102 [01:25<00:34,  1.16s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  72%|███████▏  | 73/102 [01:26<00:33,  1.15s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  73%|███████▎  | 74/102 [01:27<00:32,  1.16s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  74%|███████▎  | 75/102 [01:28<00:31,  1.16s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  75%|███████▍  | 76/102 [01:30<00:31,  1.19s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  75%|███████▌  | 77/102 [01:31<00:32,  1.29s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Epoch 1/40 - Training:  76%|███████▋  | 78/102 [01:33<00:33,  1.40s/it]
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
# Mel spectrogram shape: (64, 87)
